# %%
import face_recognition
import PIL.Image
import PIL.ImageDraw

# %%
imagem = face_recognition.load_image_file("Imagens/faces3.jpg")

# %%
faces_encontradas = face_recognition.face_locations(imagem)
len(faces_encontradas)
# Out:
# 5

# %%
faces_encontradas
# Out:
# [(124, 423, 176, 371),
#  (124, 325, 176, 273),
#  (113, 573, 164, 521),
#  (53, 232, 115, 170),
#  (170, 487, 214, 443)]

# %%
image_array = PIL.Image.fromarray(imagem)
for face in faces_encontradas:
    top, left, bottom, right = face
    if left > right:
        left, right = right, left
    if top > bottom:
        top, bottom = bottom, top
    draw = PIL.ImageDraw.Draw(image_array)
    draw.rectangle([left, top, right, bottom], outline="green", width=5)

# %%
display(image_array)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360>
